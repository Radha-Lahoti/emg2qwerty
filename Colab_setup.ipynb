# %% [markdown]
# ### Step 1: Mount the Google Drive
#
# Remember to use GPU runtime before mounting your Google Drive. (Runtime --> Change runtime type).

# %%
import os
import subprocess

# %% [markdown]
# ### Step 2: Open the project directory
#
# Replace `Your_Dir` with your own path.

# %%
# Step 1: Set up the project directory
PROJECT_DIR = "/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty"  # Change this to your local directory
os.chdir(PROJECT_DIR)
print(f"Changed working directory to {PROJECT_DIR}")
# Out:
# Changed working directory to /home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty

# %%
# Step 3: Ensure GPU is available
import torch
if torch.cuda.is_available():
    print("GPU is available!")
else:
    print("Warning: GPU not found. Training may be slow.")
# Out:
# GPU is available!

# %% [markdown]
# ### Step 3: Install required packages
#
# After installing them, Colab will require you to restart the session.

# %%
# Step 2: Install required packages
# subprocess.run(["pip", "install", "-r", "requirements.txt"], check=True)
# print("Installed required packages.")

# %% [markdown]
# ### Step 4: Start your experiments!
#
# - Remember to download and copy the dataset to this directory: `Your_Dir/emg2qwerty/data`.
# - You may now start your experiments with any scripts! Below are examples of single-user training and testing (greedy decoding).
# - **There are two ways to track the logs:**
#   - 1. Keep `--multirun`, and the logs will not be printed here, but they will be saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/submitit_logs/`.
#   - 2. Comment out `--multirun` and the logs will be printed in this notebook, but they will not be saved.

# %% [markdown]
# #### Training
#
# - The checkpoints are saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/checkpoints/`.

# %%
# Step 4: Training script (single-user training)
train_command = [
    "python3", "-m", "emg2qwerty.train",
    "user=single_user",
    "trainer.accelerator=gpu",
    "trainer.devices=1", "trainer.max_epochs=25"
]
subprocess.run(train_command, check=True)
print("Training completed.")
# Out:
# [2025-03-05 16:04:55,766][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: true
# checkpoint: null
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 25
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# [2025-03-05 16:04:55,767][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModule', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32}
# [2025-03-05 16:04:55,842][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# Global seed set to 1501
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# /home/radha/.local/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:92: UnderReviewWarning: The feature LinearWarmupCosineAnnealingLR is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   return _target_(*args, **kwargs)
#
#   | Name     | Type       | Params
# ----------------------------------------
# 0 | model    | Sequential | 7.5 M
# 1 | ctc_loss | CTCLoss    | 0
# 2 | metrics  | ModuleDict | 0
# ----------------------------------------
# 7.5 M     Trainable params
# 0         Non-trainable params
# 7.5 M     Total params
# 29.820    Total estimated model params size (MB)
# Epoch 0:  94%|█████████▍| 120/127 [00:33<00:01,  3.57it/s, loss=159, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 0:  95%|█████████▌| 121/127 [00:34<00:01,  3.49it/s, loss=159, v_num=0]
# Epoch 0:  96%|█████████▌| 122/127 [00:34<00:01,  3.49it/s, loss=159, v_num=0]
# Epoch 0:  97%|█████████▋| 123/127 [00:35<00:01,  3.51it/s, loss=159, v_num=0]
# Epoch 0:  98%|█████████▊| 124/127 [00:35<00:00,  3.53it/s, loss=159, v_num=0]
# Epoch 0:  98%|█████████▊| 125/127 [00:35<00:00,  3.54it/s, loss=159, v_num=0]
# Epoch 0:  99%|█████████▉| 126/127 [00:35<00:00,  3.56it/s, loss=159, v_num=0]
# Epoch 0: 100%|██████████| 127/127 [00:35<00:00,  3.58it/s, loss=159, v_num=0]
# Epoch 0: 100%|██████████| 127/127 [00:35<00:00,  3.58it/s, loss=159, v_num=0]
# Epoch 0, global step 120: 'val/CER' reached 1699.97791 (best 1699.97791), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=0-step=120.ckpt' as top 1
# Epoch 1:  94%|█████████▍| 120/127 [00:32<00:01,  3.74it/s, loss=3.46, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 1:  95%|█████████▌| 121/127 [00:33<00:01,  3.65it/s, loss=3.46, v_num=0]
# Epoch 1:  96%|█████████▌| 122/127 [00:33<00:01,  3.67it/s, loss=3.46, v_num=0]
# Epoch 1:  97%|█████████▋| 123/127 [00:33<00:01,  3.68it/s, loss=3.46, v_num=0]
# Epoch 1:  98%|█████████▊| 124/127 [00:33<00:00,  3.70it/s, loss=3.46, v_num=0]
# Epoch 1:  98%|█████████▊| 125/127 [00:33<00:00,  3.70it/s, loss=3.46, v_num=0]
# Epoch 1:  99%|█████████▉| 126/127 [00:33<00:00,  3.72it/s, loss=3.46, v_num=0]
# Epoch 1: 100%|██████████| 127/127 [00:33<00:00,  3.75it/s, loss=3.46, v_num=0]
# Epoch 1: 100%|██████████| 127/127 [00:33<00:00,  3.75it/s, loss=3.46, v_num=0]
# Epoch 1, global step 240: 'val/CER' reached 100.00000 (best 100.00000), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=1-step=240.ckpt' as top 1
# Epoch 2:  94%|█████████▍| 120/127 [00:31<00:01,  3.81it/s, loss=3.35, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 2:  95%|█████████▌| 121/127 [00:32<00:01,  3.70it/s, loss=3.35, v_num=0]
# Epoch 2:  96%|█████████▌| 122/127 [00:32<00:01,  3.72it/s, loss=3.35, v_num=0]
# Epoch 2:  97%|█████████▋| 123/127 [00:32<00:01,  3.74it/s, loss=3.35, v_num=0]
# Epoch 2:  98%|█████████▊| 124/127 [00:32<00:00,  3.76it/s, loss=3.35, v_num=0]
# Epoch 2:  98%|█████████▊| 125/127 [00:33<00:00,  3.77it/s, loss=3.35, v_num=0]
# Epoch 2:  99%|█████████▉| 126/127 [00:33<00:00,  3.79it/s, loss=3.35, v_num=0]
# Epoch 2: 100%|██████████| 127/127 [00:33<00:00,  3.81it/s, loss=3.35, v_num=0]
# Epoch 2: 100%|██████████| 127/127 [00:33<00:00,  3.81it/s, loss=3.35, v_num=0]
# Epoch 2, global step 360: 'val/CER' was not in top 1
# Epoch 3:  94%|█████████▍| 120/127 [00:31<00:01,  3.76it/s, loss=3.26, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 3:  95%|█████████▌| 121/127 [00:32<00:01,  3.67it/s, loss=3.26, v_num=0]
# Epoch 3:  96%|█████████▌| 122/127 [00:33<00:01,  3.69it/s, loss=3.26, v_num=0]
# Epoch 3:  97%|█████████▋| 123/127 [00:33<00:01,  3.70it/s, loss=3.26, v_num=0]
# Epoch 3:  98%|█████████▊| 124/127 [00:33<00:00,  3.72it/s, loss=3.26, v_num=0]
# Epoch 3:  98%|█████████▊| 125/127 [00:33<00:00,  3.72it/s, loss=3.26, v_num=0]
# Epoch 3:  99%|█████████▉| 126/127 [00:33<00:00,  3.74it/s, loss=3.26, v_num=0]
# Epoch 3: 100%|██████████| 127/127 [00:33<00:00,  3.76it/s, loss=3.26, v_num=0]
# Epoch 3: 100%|██████████| 127/127 [00:33<00:00,  3.76it/s, loss=3.26, v_num=0]
# Epoch 3, global step 480: 'val/CER' was not in top 1
# Epoch 4:  94%|█████████▍| 120/127 [00:30<00:01,  3.89it/s, loss=3.22, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 4:  95%|█████████▌| 121/127 [00:32<00:01,  3.77it/s, loss=3.22, v_num=0]
# Epoch 4:  96%|█████████▌| 122/127 [00:32<00:01,  3.78it/s, loss=3.22, v_num=0]
# Epoch 4:  97%|█████████▋| 123/127 [00:32<00:01,  3.80it/s, loss=3.22, v_num=0]
# Epoch 4:  98%|█████████▊| 124/127 [00:32<00:00,  3.82it/s, loss=3.22, v_num=0]
# Epoch 4:  98%|█████████▊| 125/127 [00:32<00:00,  3.84it/s, loss=3.22, v_num=0]
# Epoch 4:  99%|█████████▉| 126/127 [00:32<00:00,  3.86it/s, loss=3.22, v_num=0]
# Epoch 4: 100%|██████████| 127/127 [00:32<00:00,  3.88it/s, loss=3.22, v_num=0]
# Epoch 4: 100%|██████████| 127/127 [00:32<00:00,  3.88it/s, loss=3.22, v_num=0]
# Epoch 4, global step 600: 'val/CER' was not in top 1
# Epoch 5:  94%|█████████▍| 120/127 [00:30<00:01,  3.90it/s, loss=3.24, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 5:  95%|█████████▌| 121/127 [00:31<00:01,  3.83it/s, loss=3.24, v_num=0]
# Epoch 5:  96%|█████████▌| 122/127 [00:31<00:01,  3.85it/s, loss=3.24, v_num=0]
# Epoch 5:  97%|█████████▋| 123/127 [00:31<00:01,  3.86it/s, loss=3.24, v_num=0]
# Epoch 5:  98%|█████████▊| 124/127 [00:31<00:00,  3.88it/s, loss=3.24, v_num=0]
# Epoch 5:  98%|█████████▊| 125/127 [00:32<00:00,  3.89it/s, loss=3.24, v_num=0]
# Epoch 5:  99%|█████████▉| 126/127 [00:32<00:00,  3.91it/s, loss=3.24, v_num=0]
# Epoch 5: 100%|██████████| 127/127 [00:32<00:00,  3.93it/s, loss=3.24, v_num=0]
# Epoch 5: 100%|██████████| 127/127 [00:32<00:00,  3.93it/s, loss=3.24, v_num=0]
# Epoch 5, global step 720: 'val/CER' was not in top 1
# Epoch 6:  94%|█████████▍| 120/127 [00:27<00:01,  4.32it/s, loss=3.09, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 6:  95%|█████████▌| 121/127 [00:29<00:01,  4.17it/s, loss=3.09, v_num=0]
# Epoch 6:  96%|█████████▌| 122/127 [00:29<00:01,  4.19it/s, loss=3.09, v_num=0]
# Epoch 6:  97%|█████████▋| 123/127 [00:29<00:00,  4.21it/s, loss=3.09, v_num=0]
# Epoch 6:  98%|█████████▊| 124/127 [00:29<00:00,  4.23it/s, loss=3.09, v_num=0]
# Epoch 6:  98%|█████████▊| 125/127 [00:29<00:00,  4.23it/s, loss=3.09, v_num=0]
# Epoch 6:  99%|█████████▉| 126/127 [00:29<00:00,  4.25it/s, loss=3.09, v_num=0]
# Epoch 6: 100%|██████████| 127/127 [00:29<00:00,  4.28it/s, loss=3.09, v_num=0]
# Epoch 6: 100%|██████████| 127/127 [00:29<00:00,  4.28it/s, loss=3.09, v_num=0]
# Epoch 6, global step 840: 'val/CER' was not in top 1
# Epoch 7:  94%|█████████▍| 120/127 [00:31<00:01,  3.83it/s, loss=2.98, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 7:  95%|█████████▌| 121/127 [00:32<00:01,  3.73it/s, loss=2.98, v_num=0]
# Epoch 7:  96%|█████████▌| 122/127 [00:32<00:01,  3.75it/s, loss=2.98, v_num=0]
# Epoch 7:  97%|█████████▋| 123/127 [00:32<00:01,  3.77it/s, loss=2.98, v_num=0]
# Epoch 7:  98%|█████████▊| 124/127 [00:32<00:00,  3.78it/s, loss=2.98, v_num=0]
# Epoch 7:  98%|█████████▊| 125/127 [00:32<00:00,  3.79it/s, loss=2.98, v_num=0]
# Epoch 7:  99%|█████████▉| 126/127 [00:33<00:00,  3.81it/s, loss=2.98, v_num=0]
# Epoch 7: 100%|██████████| 127/127 [00:33<00:00,  3.83it/s, loss=2.98, v_num=0]
# Epoch 7: 100%|██████████| 127/127 [00:33<00:00,  3.83it/s, loss=2.98, v_num=0]
# Epoch 7, global step 960: 'val/CER' was not in top 1
# Epoch 8:  94%|█████████▍| 120/127 [00:31<00:01,  3.82it/s, loss=2.83, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 8:  95%|█████████▌| 121/127 [00:32<00:01,  3.72it/s, loss=2.83, v_num=0]
# Epoch 8:  96%|█████████▌| 122/127 [00:32<00:01,  3.74it/s, loss=2.83, v_num=0]
# Epoch 8:  97%|█████████▋| 123/127 [00:32<00:01,  3.76it/s, loss=2.83, v_num=0]
# Epoch 8:  98%|█████████▊| 124/127 [00:32<00:00,  3.78it/s, loss=2.83, v_num=0]
# Epoch 8:  98%|█████████▊| 125/127 [00:33<00:00,  3.78it/s, loss=2.83, v_num=0]
# Epoch 8:  99%|█████████▉| 126/127 [00:33<00:00,  3.80it/s, loss=2.83, v_num=0]
# Epoch 8: 100%|██████████| 127/127 [00:33<00:00,  3.82it/s, loss=2.83, v_num=0]
# Epoch 8: 100%|██████████| 127/127 [00:33<00:00,  3.82it/s, loss=2.83, v_num=0]
# Epoch 8, global step 1080: 'val/CER' was not in top 1
# Epoch 9:  94%|█████████▍| 120/127 [00:30<00:01,  3.95it/s, loss=2.69, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 9:  95%|█████████▌| 121/127 [00:31<00:01,  3.85it/s, loss=2.69, v_num=0]
# Epoch 9:  96%|█████████▌| 122/127 [00:31<00:01,  3.85it/s, loss=2.69, v_num=0]
# Epoch 9:  97%|█████████▋| 123/127 [00:31<00:01,  3.88it/s, loss=2.69, v_num=0]
# Epoch 9:  98%|█████████▊| 124/127 [00:31<00:00,  3.90it/s, loss=2.69, v_num=0]
# Epoch 9:  98%|█████████▊| 125/127 [00:32<00:00,  3.90it/s, loss=2.69, v_num=0]
# Epoch 9:  99%|█████████▉| 126/127 [00:32<00:00,  3.92it/s, loss=2.69, v_num=0]
# Epoch 9: 100%|██████████| 127/127 [00:32<00:00,  3.95it/s, loss=2.69, v_num=0]
# Epoch 9: 100%|██████████| 127/127 [00:32<00:00,  3.95it/s, loss=2.69, v_num=0]
# Epoch 9, global step 1200: 'val/CER' was not in top 1
# Epoch 10:  94%|█████████▍| 120/127 [00:30<00:01,  3.90it/s, loss=2.44, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 10:  95%|█████████▌| 121/127 [00:31<00:01,  3.80it/s, loss=2.44, v_num=0]
# Epoch 10:  96%|█████████▌| 122/127 [00:31<00:01,  3.82it/s, loss=2.44, v_num=0]
# Epoch 10:  97%|█████████▋| 123/127 [00:32<00:01,  3.84it/s, loss=2.44, v_num=0]
# Epoch 10:  98%|█████████▊| 124/127 [00:32<00:00,  3.86it/s, loss=2.44, v_num=0]
# Epoch 10:  98%|█████████▊| 125/127 [00:32<00:00,  3.86it/s, loss=2.44, v_num=0]
# Epoch 10:  99%|█████████▉| 126/127 [00:32<00:00,  3.88it/s, loss=2.44, v_num=0]
# Epoch 10: 100%|██████████| 127/127 [00:32<00:00,  3.90it/s, loss=2.44, v_num=0]
# Epoch 10: 100%|██████████| 127/127 [00:32<00:00,  3.90it/s, loss=2.44, v_num=0]
# Epoch 10, global step 1320: 'val/CER' reached 95.56934 (best 95.56934), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=10-step=1320.ckpt' as top 1
# Epoch 11:  94%|█████████▍| 120/127 [00:30<00:01,  3.97it/s, loss=2.34, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 11:  95%|█████████▌| 121/127 [00:31<00:01,  3.86it/s, loss=2.34, v_num=0]
# Epoch 11:  96%|█████████▌| 122/127 [00:31<00:01,  3.86it/s, loss=2.34, v_num=0]
# Epoch 11:  97%|█████████▋| 123/127 [00:31<00:01,  3.88it/s, loss=2.34, v_num=0]
# Epoch 11:  98%|█████████▊| 124/127 [00:31<00:00,  3.90it/s, loss=2.34, v_num=0]
# Epoch 11:  98%|█████████▊| 125/127 [00:32<00:00,  3.90it/s, loss=2.34, v_num=0]
# Epoch 11:  99%|█████████▉| 126/127 [00:32<00:00,  3.92it/s, loss=2.34, v_num=0]
# Epoch 11: 100%|██████████| 127/127 [00:32<00:00,  3.94it/s, loss=2.34, v_num=0]
# Epoch 11: 100%|██████████| 127/127 [00:32<00:00,  3.94it/s, loss=2.34, v_num=0]
# Epoch 11, global step 1440: 'val/CER' reached 90.87284 (best 90.87284), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=11-step=1440.ckpt' as top 1
# Epoch 12:  94%|█████████▍| 120/127 [00:31<00:01,  3.86it/s, loss=2.27, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 12:  95%|█████████▌| 121/127 [00:32<00:01,  3.74it/s, loss=2.27, v_num=0]
# Epoch 12:  96%|█████████▌| 122/127 [00:32<00:01,  3.76it/s, loss=2.27, v_num=0]
# Epoch 12:  97%|█████████▋| 123/127 [00:32<00:01,  3.78it/s, loss=2.27, v_num=0]
# Epoch 12:  98%|█████████▊| 124/127 [00:32<00:00,  3.80it/s, loss=2.27, v_num=0]
# Epoch 12:  98%|█████████▊| 125/127 [00:32<00:00,  3.80it/s, loss=2.27, v_num=0]
# Epoch 12:  99%|█████████▉| 126/127 [00:32<00:00,  3.82it/s, loss=2.27, v_num=0]
# Epoch 12: 100%|██████████| 127/127 [00:33<00:00,  3.84it/s, loss=2.27, v_num=0]
# Epoch 12: 100%|██████████| 127/127 [00:33<00:00,  3.84it/s, loss=2.27, v_num=0]
# Epoch 12, global step 1560: 'val/CER' reached 88.94550 (best 88.94550), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=12-step=1560.ckpt' as top 1
# Epoch 13:  94%|█████████▍| 120/127 [00:30<00:01,  3.93it/s, loss=2.18, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 13:  95%|█████████▌| 121/127 [00:31<00:01,  3.82it/s, loss=2.18, v_num=0]
# Epoch 13:  96%|█████████▌| 122/127 [00:31<00:01,  3.84it/s, loss=2.18, v_num=0]
# Epoch 13:  97%|█████████▋| 123/127 [00:31<00:01,  3.86it/s, loss=2.18, v_num=0]
# Epoch 13:  98%|█████████▊| 124/127 [00:31<00:00,  3.88it/s, loss=2.18, v_num=0]
# Epoch 13:  98%|█████████▊| 125/127 [00:32<00:00,  3.87it/s, loss=2.18, v_num=0]
# Epoch 13:  99%|█████████▉| 126/127 [00:32<00:00,  3.89it/s, loss=2.18, v_num=0]
# Epoch 13: 100%|██████████| 127/127 [00:32<00:00,  3.92it/s, loss=2.18, v_num=0]
# Epoch 13: 100%|██████████| 127/127 [00:32<00:00,  3.91it/s, loss=2.18, v_num=0]
# Epoch 13, global step 1680: 'val/CER' reached 82.49889 (best 82.49889), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=13-step=1680.ckpt' as top 1
# Epoch 14:  94%|█████████▍| 120/127 [00:30<00:01,  3.89it/s, loss=2.16, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 14:  95%|█████████▌| 121/127 [00:31<00:01,  3.78it/s, loss=2.16, v_num=0]
# Epoch 14:  96%|█████████▌| 122/127 [00:32<00:01,  3.79it/s, loss=2.16, v_num=0]
# Epoch 14:  97%|█████████▋| 123/127 [00:32<00:01,  3.81it/s, loss=2.16, v_num=0]
# Epoch 14:  98%|█████████▊| 124/127 [00:32<00:00,  3.83it/s, loss=2.16, v_num=0]
# Epoch 14:  98%|█████████▊| 125/127 [00:32<00:00,  3.83it/s, loss=2.16, v_num=0]
# Epoch 14:  99%|█████████▉| 126/127 [00:32<00:00,  3.85it/s, loss=2.16, v_num=0]
# Epoch 14: 100%|██████████| 127/127 [00:32<00:00,  3.88it/s, loss=2.16, v_num=0]
# Epoch 14: 100%|██████████| 127/127 [00:32<00:00,  3.88it/s, loss=2.16, v_num=0]
# Epoch 14, global step 1800: 'val/CER' was not in top 1
# Epoch 15:  94%|█████████▍| 120/127 [00:30<00:01,  3.98it/s, loss=2, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 15:  95%|█████████▌| 121/127 [00:31<00:01,  3.87it/s, loss=2, v_num=0]
# Epoch 15:  96%|█████████▌| 122/127 [00:31<00:01,  3.88it/s, loss=2, v_num=0]
# Epoch 15:  97%|█████████▋| 123/127 [00:31<00:01,  3.90it/s, loss=2, v_num=0]
# Epoch 15:  98%|█████████▊| 124/127 [00:31<00:00,  3.92it/s, loss=2, v_num=0]
# Epoch 15:  98%|█████████▊| 125/127 [00:31<00:00,  3.92it/s, loss=2, v_num=0]
# Epoch 15:  99%|█████████▉| 126/127 [00:31<00:00,  3.94it/s, loss=2, v_num=0]
# Epoch 15: 100%|██████████| 127/127 [00:32<00:00,  3.96it/s, loss=2, v_num=0]
# Epoch 15: 100%|██████████| 127/127 [00:32<00:00,  3.96it/s, loss=2, v_num=0]
# Epoch 15, global step 1920: 'val/CER' reached 73.48250 (best 73.48250), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=15-step=1920.ckpt' as top 1
# Epoch 16:  94%|█████████▍| 120/127 [00:30<00:01,  3.94it/s, loss=1.98, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 16:  95%|█████████▌| 121/127 [00:31<00:01,  3.83it/s, loss=1.98, v_num=0]
# Epoch 16:  96%|█████████▌| 122/127 [00:31<00:01,  3.84it/s, loss=1.98, v_num=0]
# Epoch 16:  97%|█████████▋| 123/127 [00:31<00:01,  3.86it/s, loss=1.98, v_num=0]
# Epoch 16:  98%|█████████▊| 124/127 [00:31<00:00,  3.89it/s, loss=1.98, v_num=0]
# Epoch 16:  98%|█████████▊| 125/127 [00:32<00:00,  3.88it/s, loss=1.98, v_num=0]
# Epoch 16:  99%|█████████▉| 126/127 [00:32<00:00,  3.90it/s, loss=1.98, v_num=0]
# Epoch 16: 100%|██████████| 127/127 [00:32<00:00,  3.92it/s, loss=1.98, v_num=0]
# Epoch 16: 100%|██████████| 127/127 [00:32<00:00,  3.92it/s, loss=1.98, v_num=0]
# Epoch 16, global step 2040: 'val/CER' was not in top 1
# Epoch 17:  94%|█████████▍| 120/127 [00:31<00:01,  3.81it/s, loss=1.84, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 17:  95%|█████████▌| 121/127 [00:32<00:01,  3.69it/s, loss=1.84, v_num=0]
# Epoch 17:  96%|█████████▌| 122/127 [00:32<00:01,  3.71it/s, loss=1.84, v_num=0]
# Epoch 17:  97%|█████████▋| 123/127 [00:32<00:01,  3.73it/s, loss=1.84, v_num=0]
# Epoch 17:  98%|█████████▊| 124/127 [00:33<00:00,  3.75it/s, loss=1.84, v_num=0]
# Epoch 17:  98%|█████████▊| 125/127 [00:33<00:00,  3.75it/s, loss=1.84, v_num=0]
# Epoch 17:  99%|█████████▉| 126/127 [00:33<00:00,  3.77it/s, loss=1.84, v_num=0]
# Epoch 17: 100%|██████████| 127/127 [00:33<00:00,  3.79it/s, loss=1.84, v_num=0]
# Epoch 17: 100%|██████████| 127/127 [00:33<00:00,  3.79it/s, loss=1.84, v_num=0]
# Epoch 17, global step 2160: 'val/CER' reached 61.01019 (best 61.01019), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=17-step=2160.ckpt' as top 1
# Epoch 18:  94%|█████████▍| 120/127 [00:30<00:01,  3.88it/s, loss=1.81, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 18:  95%|█████████▌| 121/127 [00:32<00:01,  3.76it/s, loss=1.81, v_num=0]
# Epoch 18:  96%|█████████▌| 122/127 [00:32<00:01,  3.78it/s, loss=1.81, v_num=0]
# Epoch 18:  97%|█████████▋| 123/127 [00:32<00:01,  3.80it/s, loss=1.81, v_num=0]
# Epoch 18:  98%|█████████▊| 124/127 [00:32<00:00,  3.82it/s, loss=1.81, v_num=0]
# Epoch 18:  98%|█████████▊| 125/127 [00:32<00:00,  3.83it/s, loss=1.81, v_num=0]
# Epoch 18:  99%|█████████▉| 126/127 [00:32<00:00,  3.85it/s, loss=1.81, v_num=0]
# Epoch 18: 100%|██████████| 127/127 [00:32<00:00,  3.87it/s, loss=1.81, v_num=0]
# Epoch 18: 100%|██████████| 127/127 [00:32<00:00,  3.87it/s, loss=1.81, v_num=0]
# Epoch 18, global step 2280: 'val/CER' reached 60.83297 (best 60.83297), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=18-step=2280.ckpt' as top 1
# Epoch 19:  94%|█████████▍| 120/127 [00:31<00:01,  3.87it/s, loss=1.68, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 19:  95%|█████████▌| 121/127 [00:32<00:01,  3.75it/s, loss=1.68, v_num=0]
# Epoch 19:  96%|█████████▌| 122/127 [00:32<00:01,  3.77it/s, loss=1.68, v_num=0]
# Epoch 19:  97%|█████████▋| 123/127 [00:32<00:01,  3.79it/s, loss=1.68, v_num=0]
# Epoch 19:  98%|█████████▊| 124/127 [00:32<00:00,  3.81it/s, loss=1.68, v_num=0]
# Epoch 19:  98%|█████████▊| 125/127 [00:32<00:00,  3.81it/s, loss=1.68, v_num=0]
# Epoch 19:  99%|█████████▉| 126/127 [00:32<00:00,  3.83it/s, loss=1.68, v_num=0]
# Epoch 19: 100%|██████████| 127/127 [00:32<00:00,  3.85it/s, loss=1.68, v_num=0]
# Epoch 19: 100%|██████████| 127/127 [00:32<00:00,  3.85it/s, loss=1.68, v_num=0]
# Epoch 19, global step 2400: 'val/CER' reached 56.44661 (best 56.44661), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=19-step=2400.ckpt' as top 1
# Epoch 20:  94%|█████████▍| 120/127 [00:30<00:01,  3.97it/s, loss=1.64, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 20:  95%|█████████▌| 121/127 [00:31<00:01,  3.84it/s, loss=1.64, v_num=0]
# Epoch 20:  96%|█████████▌| 122/127 [00:31<00:01,  3.86it/s, loss=1.64, v_num=0]
# Epoch 20:  97%|█████████▋| 123/127 [00:31<00:01,  3.88it/s, loss=1.64, v_num=0]
# Epoch 20:  98%|█████████▊| 124/127 [00:31<00:00,  3.90it/s, loss=1.64, v_num=0]
# Epoch 20:  98%|█████████▊| 125/127 [00:32<00:00,  3.90it/s, loss=1.64, v_num=0]
# Epoch 20:  99%|█████████▉| 126/127 [00:32<00:00,  3.92it/s, loss=1.64, v_num=0]
# Epoch 20: 100%|██████████| 127/127 [00:32<00:00,  3.94it/s, loss=1.64, v_num=0]
# Epoch 20: 100%|██████████| 127/127 [00:32<00:00,  3.94it/s, loss=1.64, v_num=0]
# Epoch 20, global step 2520: 'val/CER' reached 54.94019 (best 54.94019), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=20-step=2520.ckpt' as top 1
# Epoch 21:  94%|█████████▍| 120/127 [00:30<00:01,  3.89it/s, loss=1.58, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 21:  95%|█████████▌| 121/127 [00:31<00:01,  3.78it/s, loss=1.58, v_num=0]
# Epoch 21:  96%|█████████▌| 122/127 [00:32<00:01,  3.80it/s, loss=1.58, v_num=0]
# Epoch 21:  97%|█████████▋| 123/127 [00:32<00:01,  3.82it/s, loss=1.58, v_num=0]
# Epoch 21:  98%|█████████▊| 124/127 [00:32<00:00,  3.84it/s, loss=1.58, v_num=0]
# Epoch 21:  98%|█████████▊| 125/127 [00:32<00:00,  3.84it/s, loss=1.58, v_num=0]
# Epoch 21:  99%|█████████▉| 126/127 [00:32<00:00,  3.86it/s, loss=1.58, v_num=0]
# Epoch 21: 100%|██████████| 127/127 [00:32<00:00,  3.88it/s, loss=1.58, v_num=0]
# Epoch 21: 100%|██████████| 127/127 [00:32<00:00,  3.88it/s, loss=1.58, v_num=0]
# Epoch 21, global step 2640: 'val/CER' reached 52.99070 (best 52.99070), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=21-step=2640.ckpt' as top 1
# Epoch 22:  94%|█████████▍| 120/127 [00:29<00:01,  4.00it/s, loss=1.57, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 22:  95%|█████████▌| 121/127 [00:31<00:01,  3.90it/s, loss=1.57, v_num=0]
# Epoch 22:  96%|█████████▌| 122/127 [00:31<00:01,  3.92it/s, loss=1.57, v_num=0]
# Epoch 22:  97%|█████████▋| 123/127 [00:31<00:01,  3.93it/s, loss=1.57, v_num=0]
# Epoch 22:  98%|█████████▊| 124/127 [00:31<00:00,  3.95it/s, loss=1.57, v_num=0]
# Epoch 22:  98%|█████████▊| 125/127 [00:31<00:00,  3.96it/s, loss=1.57, v_num=0]
# Epoch 22:  99%|█████████▉| 126/127 [00:31<00:00,  3.98it/s, loss=1.57, v_num=0]
# Epoch 22: 100%|██████████| 127/127 [00:31<00:00,  4.00it/s, loss=1.57, v_num=0]
# Epoch 22: 100%|██████████| 127/127 [00:31<00:00,  4.00it/s, loss=1.57, v_num=0]
# Epoch 22, global step 2760: 'val/CER' was not in top 1
# Epoch 23:  94%|█████████▍| 120/127 [00:30<00:01,  3.89it/s, loss=1.55, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 23:  95%|█████████▌| 121/127 [00:31<00:01,  3.79it/s, loss=1.55, v_num=0]
# Epoch 23:  96%|█████████▌| 122/127 [00:32<00:01,  3.80it/s, loss=1.55, v_num=0]
# Epoch 23:  97%|█████████▋| 123/127 [00:32<00:01,  3.82it/s, loss=1.55, v_num=0]
# Epoch 23:  98%|█████████▊| 124/127 [00:32<00:00,  3.84it/s, loss=1.55, v_num=0]
# Epoch 23:  98%|█████████▊| 125/127 [00:32<00:00,  3.83it/s, loss=1.55, v_num=0]
# Epoch 23:  99%|█████████▉| 126/127 [00:32<00:00,  3.85it/s, loss=1.55, v_num=0]
# Epoch 23: 100%|██████████| 127/127 [00:32<00:00,  3.88it/s, loss=1.55, v_num=0]
# Epoch 23: 100%|██████████| 127/127 [00:32<00:00,  3.88it/s, loss=1.55, v_num=0]
# Epoch 23, global step 2880: 'val/CER' reached 49.37971 (best 49.37971), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=23-step=2880.ckpt' as top 1
# Epoch 24:  94%|█████████▍| 120/127 [00:30<00:01,  3.94it/s, loss=1.54, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 24:  95%|█████████▌| 121/127 [00:31<00:01,  3.82it/s, loss=1.54, v_num=0]
# Epoch 24:  96%|█████████▌| 122/127 [00:31<00:01,  3.84it/s, loss=1.54, v_num=0]
# Epoch 24:  97%|█████████▋| 123/127 [00:31<00:01,  3.86it/s, loss=1.54, v_num=0]
# Epoch 24:  98%|█████████▊| 124/127 [00:31<00:00,  3.88it/s, loss=1.54, v_num=0]
# Epoch 24:  98%|█████████▊| 125/127 [00:32<00:00,  3.87it/s, loss=1.54, v_num=0]
# Epoch 24:  99%|█████████▉| 126/127 [00:32<00:00,  3.89it/s, loss=1.54, v_num=0]
# Epoch 24: 100%|██████████| 127/127 [00:32<00:00,  3.92it/s, loss=1.54, v_num=0]
# Epoch 24: 100%|██████████| 127/127 [00:32<00:00,  3.92it/s, loss=1.54, v_num=0]
# Epoch 24, global step 3000: 'val/CER' was not in top 1
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 127/127 [00:32<00:00,  3.89it/s, loss=1.54, v_num=0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:00<00:00,  9.68it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          val/CER             49.37970733642578
#          val/DER            1.7279574871063232
#          val/IER            28.799291610717773
#          val/SER            18.852458953857422
#         val/loss            1.4434155225753784
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test/CER            46.163822174072266
#         test/DER            0.41063323616981506
#         test/IER            26.410200119018555
#         test/SER            19.342987060546875
#         test/loss           1.3353990316390991
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# {'val_metrics': [{'val/loss': 1.4434155225753784,
#                   'val/CER': 49.37970733642578,
#                   'val/IER': 28.799291610717773,
#                   'val/DER': 1.7279574871063232,
#                   'val/SER': 18.852458953857422}],
#  'test_metrics': [{'test/loss': 1.3353990316390991,
#                    'test/CER': 46.163822174072266,
#                    'test/IER': 26.410200119018555,
#                    'test/DER': 0.41063323616981506,
#                    'test/SER': 19.342987060546875}],
#  'best_checkpoint': '/home/radha/Desktop/courses/ECE '
#                     'C247/project_git/emg2qwerty/logs/2025-03-05/16-04-55/checkpoints/epoch=23-step=2880.ckpt'}
# Training completed.

# %% [markdown]
# #### Testing:
#
# - Replace `Your_Path_to_Checkpoint` with your checkpoint path.

# %%
# Step 5: Testing script (replace with actual checkpoint path)
CHECKPOINT_PATH = "'/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/13-48-35/checkpoints/last.ckpt'"  # Update this path

test_command = [
    "python3", "-m", "emg2qwerty.train",
    "user=single_user",
    f"checkpoint={CHECKPOINT_PATH}",
    "train=False",
    "trainer.accelerator=gpu",
    "decoder=ctc_greedy",
    "hydra.launcher.mem_gb=64"
]
subprocess.run(test_command, check=True)
print("Testing completed.")
# Out:
# [2025-03-05 16:19:06,491][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: false
# checkpoint: /home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/13-48-35/checkpoints/last.ckpt
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 150
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# [2025-03-05 16:19:06,494][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModule', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32}
# [2025-03-05 16:19:06,574][__main__][INFO] - Loading module from checkpoint /home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/13-48-35/checkpoints/last.ckpt
# Global seed set to 1501
# Error executing job with overrides: ['user=single_user', "checkpoint='/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/13-48-35/checkpoints/last.ckpt'", 'train=False', 'trainer.accelerator=gpu', 'decoder=ctc_greedy']
# Traceback (most recent call last):
#   File "/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/emg2qwerty/train.py", line 67, in main
#     module = module.load_from_checkpoint(
#   File "/home/radha/.local/lib/python3.10/site-packages/pytorch_lightning/core/saving.py", line 137, in load_from_checkpoint
#     return _load_from_checkpoint(
#   File "/home/radha/.local/lib/python3.10/site-packages/pytorch_lightning/core/saving.py", line 180, in _load_from_checkpoint
#     return _load_state(cls, checkpoint, strict=strict, **kwargs)
#   File "/home/radha/.local/lib/python3.10/site-packages/pytorch_lightning/core/saving.py", line 238, in _load_state
#     keys = obj.load_state_dict(checkpoint["state_dict"], strict=strict)
#   File "/home/radha/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 2189, in load_state_dict
#     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# RuntimeError: Error(s) in loading state_dict for TDSConvCTCModule:
# 	Missing key(s) in state_dict: "model.3.tds_rnn_blocks.0.rnn.weight_ih_l0", "model.3.tds_rnn_blocks.0.rnn.weight_hh_l0", "model.3.tds_rnn_blocks.0.rnn.bias_ih_l0", "model.3.tds_rnn_blocks.0.rnn.bias_hh_l0", "model.3.tds_rnn_blocks.0.projection.weight", "model.3.tds_rnn_blocks.0.projection.bias", "model.3.tds_rnn_blocks.0.layer_norm.weight", "model.3.tds_rnn_blocks.0.layer_norm.bias", "model.3.tds_rnn_blocks.1.fc_block.0.weight", "model.3.tds_rnn_blocks.1.fc_block.0.bias", "model.3.tds_rnn_blocks.1.fc_block.2.weight", "model.3.tds_rnn_blocks.1.fc_block.2.bias", "model.3.tds_rnn_blocks.1.layer_norm.weight", "model.3.tds_rnn_blocks.1.layer_norm.bias", "model.3.tds_rnn_blocks.2.rnn.weight_ih_l0", "model.3.tds_rnn_blocks.2.rnn.weight_hh_l0", "model.3.tds_rnn_blocks.2.rnn.bias_ih_l0", "model.3.tds_rnn_blocks.2.rnn.bias_hh_l0", "model.3.tds_rnn_blocks.2.projection.weight", "model.3.tds_rnn_blocks.2.projection.bias", "model.3.tds_rnn_blocks.2.layer_norm.weight", "model.3.tds_rnn_blocks.2.layer_norm.bias", "model.3.tds_rnn_blocks.3.fc_block.0.weight", "model.3.tds_rnn_blocks.3.fc_block.0.bias", "model.3.tds_rnn_blocks.3.fc_block.2.weight", "model.3.tds_rnn_blocks.3.fc_block.2.bias", "model.3.tds_rnn_blocks.3.layer_norm.weight", "model.3.tds_rnn_blocks.3.layer_norm.bias", "model.3.tds_rnn_blocks.4.rnn.weight_ih_l0", "model.3.tds_rnn_blocks.4.rnn.weight_hh_l0", "model.3.tds_rnn_blocks.4.rnn.bias_ih_l0", "model.3.tds_rnn_blocks.4.rnn.bias_hh_l0", "model.3.tds_rnn_blocks.4.projection.weight", "model.3.tds_rnn_blocks.4.projection.bias", "model.3.tds_rnn_blocks.4.layer_norm.weight", "model.3.tds_rnn_blocks.4.layer_norm.bias", "model.3.tds_rnn_blocks.5.fc_block.0.weight", "model.3.tds_rnn_blocks.5.fc_block.0.bias", "model.3.tds_rnn_blocks.5.fc_block.2.weight", "model.3.tds_rnn_blocks.5.fc_block.2.bias", "model.3.tds_rnn_blocks.5.layer_norm.weight", "model.3.tds_rnn_blocks.5.layer_norm.bias", "model.3.tds_rnn_blocks.6.rnn.weight_ih_l0", "model.3.tds_rnn_blocks.6.rnn.weight_hh_l0", "model.3.tds_rnn_blocks.6.rnn.bias_ih_l0", "model.3.tds_rnn_blocks.6.rnn.bias_hh_l0", "model.3.tds_rnn_blocks.6.projection.weight", "model.3.tds_rnn_blocks.6.projection.bias", "model.3.tds_rnn_blocks.6.layer_norm.weight", "model.3.tds_rnn_blocks.6.layer_norm.bias", "model.3.tds_rnn_blocks.7.fc_block.0.weight", "model.3.tds_rnn_blocks.7.fc_block.0.bias", "model.3.tds_rnn_blocks.7.fc_block.2.weight", "model.3.tds_rnn_blocks.7.fc_block.2.bias", "model.3.tds_rnn_blocks.7.layer_norm.weight", "model.3.tds_rnn_blocks.7.layer_norm.bias".
# 	Unexpected key(s) in state_dict: "model.3.tds_conv_blocks.0.conv2d.weight", "model.3.tds_conv_blocks.0.conv2d.bias", "model.3.tds_conv_blocks.0.layer_norm.weight", "model.3.tds_conv_blocks.0.layer_norm.bias", "model.3.tds_conv_blocks.1.fc_block.0.weight", "model.3.tds_conv_blocks.1.fc_block.0.bias", "model.3.tds_conv_blocks.1.fc_block.2.weight", "model.3.tds_conv_blocks.1.fc_block.2.bias", "model.3.tds_conv_blocks.1.layer_norm.weight", "model.3.tds_conv_blocks.1.layer_norm.bias", "model.3.tds_conv_blocks.2.conv2d.weight", "model.3.tds_conv_blocks.2.conv2d.bias", "model.3.tds_conv_blocks.2.layer_norm.weight", "model.3.tds_conv_blocks.2.layer_norm.bias", "model.3.tds_conv_blocks.3.fc_block.0.weight", "model.3.tds_conv_blocks.3.fc_block.0.bias", "model.3.tds_conv_blocks.3.fc_block.2.weight", "model.3.tds_conv_blocks.3.fc_block.2.bias", "model.3.tds_conv_blocks.3.layer_norm.weight", "model.3.tds_conv_blocks.3.layer_norm.bias", "model.3.tds_conv_blocks.4.conv2d.weight", "model.3.tds_conv_blocks.4.conv2d.bias", "model.3.tds_conv_blocks.4.layer_norm.weight", "model.3.tds_conv_blocks.4.layer_norm.bias", "model.3.tds_conv_blocks.5.fc_block.0.weight", "model.3.tds_conv_blocks.5.fc_block.0.bias", "model.3.tds_conv_blocks.5.fc_block.2.weight", "model.3.tds_conv_blocks.5.fc_block.2.bias", "model.3.tds_conv_blocks.5.layer_norm.weight", "model.3.tds_conv_blocks.5.layer_norm.bias", "model.3.tds_conv_blocks.6.conv2d.weight", "model.3.tds_conv_blocks.6.conv2d.bias", "model.3.tds_conv_blocks.6.layer_norm.weight", "model.3.tds_conv_blocks.6.layer_norm.bias", "model.3.tds_conv_blocks.7.fc_block.0.weight", "model.3.tds_conv_blocks.7.fc_block.0.bias", "model.3.tds_conv_blocks.7.fc_block.2.weight", "model.3.tds_conv_blocks.7.fc_block.2.bias", "model.3.tds_conv_blocks.7.layer_norm.weight", "model.3.tds_conv_blocks.7.layer_norm.bias".
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 13
#       2 CHECKPOINT_PATH = "'/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/13-48-35/checkpoints/last.ckpt'"  # Update this path
#       4 test_command = [
#       5     "python3", "-m", "emg2qwerty.train",
#       6     "user=single_user",
#    (...)
#      11     "hydra.launcher.mem_gb=64"
#      12 ]
# ---> 13 subprocess.run(test_command, check=True)
#      14 print("Testing completed.")
#
# File /usr/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['python3', '-m', 'emg2qwerty.train', 'user=single_user', "checkpoint='/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-05/13-48-35/checkpoints/last.ckpt'", 'train=False', 'trainer.accelerator=gpu', 'decoder=ctc_greedy', 'hydra.launcher.mem_gb=64']' returned non-zero exit status 1.
