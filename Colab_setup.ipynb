# %%
import os
import subprocess

# %% [markdown]
# ### Step 1: Open the project directory

# %%
# Step 1: Set up the project directory
PROJECT_DIR = "/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty"  # Change this to your local directory
os.chdir(PROJECT_DIR)
print(f"Changed working directory to {PROJECT_DIR}")
# Out:
# Changed working directory to /home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty

# %% [markdown]
# ### Step 2: Ensure GPU is available
# If GPU is not available, change "trainer.accelerator=gpu" to "trainer.accelerator=cpu" in the training command.

# %%
import torch
if torch.cuda.is_available():
    print("GPU is available!")
else:
    print("Warning: GPU not found. Training may be slow.")
# Out:
# GPU is available!

# %% [markdown]
# ### Step 3: Install required packages
#
# After installing them, you may need to restart the jupyter notebook.

# %%
subprocess.run(["pip", "install", "-r", "requirements.txt"], check=True)
print("Installed required packages.")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/stepanhruda/camel-kenlm.git@a6e906b2b30497dd999cb9c84c42c5111f8616e0 (from -r requirements.txt (line 31))
#   Cloning https://github.com/stepanhruda/camel-kenlm.git (to revision a6e906b2b30497dd999cb9c84c42c5111f8616e0) to /tmp/pip-req-build-o_9klali
#   Running command git clone --filter=blob:none --quiet https://github.com/stepanhruda/camel-kenlm.git /tmp/pip-req-build-o_9klali
#   Running command git rev-parse -q --verify 'sha^a6e906b2b30497dd999cb9c84c42c5111f8616e0'
#   Running command git fetch -q https://github.com/stepanhruda/camel-kenlm.git a6e906b2b30497dd999cb9c84c42c5111f8616e0
#   Running command git checkout -q a6e906b2b30497dd999cb9c84c42c5111f8616e0
#   Resolved https://github.com/stepanhruda/camel-kenlm.git to commit a6e906b2b30497dd999cb9c84c42c5111f8616e0
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: click==8.1.7 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: datasets==2.19.2 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.19.2)
# Requirement already satisfied: h5py==3.11.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (3.11.0)
# Requirement already satisfied: hydra-core==1.3.2 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: hydra-submitit-launcher==1.2.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: hypothesis==6.97.6 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (6.97.6)
# Requirement already satisfied: lightning-bolts==0.7.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: mne-bids==0.15.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (0.15.0)
# Requirement already satisfied: nltk==3.8.1 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (3.8.1)
# Requirement already satisfied: numpy==1.24.4 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (1.24.4)
# Requirement already satisfied: omegaconf==2.3.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (2.3.0)
# Requirement already satisfied: pandas==2.0.3 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (2.0.3)
# Requirement already satisfied: pip==24.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (24.0)
# Requirement already satisfied: pre-commit==3.7.1 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (3.7.1)
# Requirement already satisfied: pytest-benchmark==4.0.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (4.0.0)
# Requirement already satisfied: pytest-cov==5.0.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (5.0.0)
# Requirement already satisfied: pytest-env==1.1.3 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (1.1.3)
# Requirement already satisfied: pytest-mock==3.14.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (3.14.0)
# Requirement already satisfied: pytest-rerunfailures==14.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (14.0)
# Requirement already satisfied: pytest-xdist==3.5.0 in /home/radha/.local/lib/python3.10/site-packages (from pytest-xdist[psutil]==3.5.0->-r requirements.txt (line 20)) (3.5.0)
# Requirement already satisfied: pytest==7.4.4 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (7.4.4)
# Requirement already satisfied: python-levenshtein==0.12.2 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (0.12.2)
# Requirement already satisfied: pytorch-lightning==1.8.6 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (1.8.6)
# Requirement already satisfied: torch==2.3.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (2.3.0)
# Requirement already satisfied: scipy==1.10.1 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (1.10.1)
# Requirement already satisfied: setuptools==69.5.1 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (69.5.1)
# Requirement already satisfied: torchaudio==2.3.0 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (2.3.0)
# Requirement already satisfied: torchmetrics==0.11.4 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.11.4)
# Requirement already satisfied: trio==0.23.2 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (0.23.2)
# Requirement already satisfied: unidecode==1.3.8 in /home/radha/.local/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (1.3.8)
# Requirement already satisfied: filelock in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (19.0.1)
# Requirement already satisfied: pyarrow-hotfix in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (0.3.8)
# Requirement already satisfied: requests>=2.32.1 in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: xxhash in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: multiprocess in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /home/radha/.local/lib/python3.10/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets==2.19.2->-r requirements.txt (line 2)) (2024.3.1)
# Requirement already satisfied: aiohttp in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (3.11.13)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (0.29.2)
# Requirement already satisfied: packaging in /home/radha/.local/lib/python3.10/site-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from datasets==2.19.2->-r requirements.txt (line 2)) (5.4.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/radha/.local/lib/python3.10/site-packages (from hydra-core==1.3.2->-r requirements.txt (line 4)) (4.9.3)
# Requirement already satisfied: submitit>=1.3.3 in /home/radha/.local/lib/python3.10/site-packages (from hydra-submitit-launcher==1.2.0->-r requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/radha/.local/lib/python3.10/site-packages (from hypothesis==6.97.6->-r requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /home/radha/.local/lib/python3.10/site-packages (from hypothesis==6.97.6->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0 in /home/radha/.local/lib/python3.10/site-packages (from hypothesis==6.97.6->-r requirements.txt (line 6)) (1.1.2)
# Requirement already satisfied: lightning-utilities>0.3.1 in /home/radha/.local/lib/python3.10/site-packages (from lightning-bolts==0.7.0->-r requirements.txt (line 7)) (0.13.1)
# Requirement already satisfied: torchvision>=0.10.0 in /home/radha/.local/lib/python3.10/site-packages (from lightning-bolts==0.7.0->-r requirements.txt (line 7)) (0.18.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/radha/.local/lib/python3.10/site-packages (from lightning-bolts==0.7.0->-r requirements.txt (line 7)) (2.19.0)
# Requirement already satisfied: mne>=1.5 in /home/radha/.local/lib/python3.10/site-packages (from mne-bids==0.15.0->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: joblib in /home/radha/.local/lib/python3.10/site-packages (from nltk==3.8.1->-r requirements.txt (line 9)) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/radha/.local/lib/python3.10/site-packages (from nltk==3.8.1->-r requirements.txt (line 9)) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/radha/.local/lib/python3.10/site-packages (from pandas==2.0.3->-r requirements.txt (line 12)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas==2.0.3->-r requirements.txt (line 12)) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/radha/.local/lib/python3.10/site-packages (from pandas==2.0.3->-r requirements.txt (line 12)) (2025.1)
# Requirement already satisfied: cfgv>=2.0.0 in /home/radha/.local/lib/python3.10/site-packages (from pre-commit==3.7.1->-r requirements.txt (line 14)) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /home/radha/.local/lib/python3.10/site-packages (from pre-commit==3.7.1->-r requirements.txt (line 14)) (2.6.8)
# Requirement already satisfied: nodeenv>=0.11.1 in /home/radha/.local/lib/python3.10/site-packages (from pre-commit==3.7.1->-r requirements.txt (line 14)) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /home/radha/.local/lib/python3.10/site-packages (from pre-commit==3.7.1->-r requirements.txt (line 14)) (20.29.2)
# Requirement already satisfied: py-cpuinfo in /home/radha/.local/lib/python3.10/site-packages (from pytest-benchmark==4.0.0->-r requirements.txt (line 15)) (9.0.0)
# Requirement already satisfied: coverage>=5.2.1 in /home/radha/.local/lib/python3.10/site-packages (from coverage[toml]>=5.2.1->pytest-cov==5.0.0->-r requirements.txt (line 16)) (7.6.12)
# Requirement already satisfied: tomli>=2.0.1 in /home/radha/.local/lib/python3.10/site-packages (from pytest-env==1.1.3->-r requirements.txt (line 17)) (2.0.1)
# Requirement already satisfied: execnet>=1.1 in /home/radha/.local/lib/python3.10/site-packages (from pytest-xdist==3.5.0->pytest-xdist[psutil]==3.5.0->-r requirements.txt (line 20)) (2.1.1)
# Requirement already satisfied: iniconfig in /home/radha/.local/lib/python3.10/site-packages (from pytest==7.4.4->-r requirements.txt (line 21)) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/radha/.local/lib/python3.10/site-packages (from pytest==7.4.4->-r requirements.txt (line 21)) (1.5.0)
# Requirement already satisfied: tensorboardX>=2.2 in /home/radha/.local/lib/python3.10/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 23)) (2.6.2.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/radha/.local/lib/python3.10/site-packages (from pytorch-lightning==1.8.6->-r requirements.txt (line 23)) (4.12.2)
# Requirement already satisfied: sympy in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (1.13.1)
# Requirement already satisfied: networkx in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (3.4.2)
# Requirement already satisfied: jinja2 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /home/radha/.local/lib/python3.10/site-packages (from torch==2.3.0->-r requirements.txt (line 24)) (2.3.0)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from trio==0.23.2->-r requirements.txt (line 29)) (3.3)
# Requirement already satisfied: outcome in /home/radha/.local/lib/python3.10/site-packages (from trio==0.23.2->-r requirements.txt (line 29)) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /home/radha/.local/lib/python3.10/site-packages (from trio==0.23.2->-r requirements.txt (line 29)) (1.3.0)
# Requirement already satisfied: psutil>=3.0 in /home/radha/.local/lib/python3.10/site-packages (from pytest-xdist[psutil]==3.5.0->-r requirements.txt (line 20)) (5.9.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/radha/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->-r requirements.txt (line 24)) (12.4.127)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/radha/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (2.4.8)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/radha/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/radha/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/radha/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/radha/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/radha/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/radha/.local/lib/python3.10/site-packages (from aiohttp->datasets==2.19.2->-r requirements.txt (line 2)) (1.18.3)
# Requirement already satisfied: decorator in /home/radha/.local/lib/python3.10/site-packages (from mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: lazy-loader>=0.3 in /home/radha/.local/lib/python3.10/site-packages (from mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (0.4)
# Requirement already satisfied: matplotlib>=3.6 in /home/radha/.local/lib/python3.10/site-packages (from mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (3.7.1)
# Requirement already satisfied: pooch>=1.5 in /home/radha/.local/lib/python3.10/site-packages (from mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (1.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas==2.0.3->-r requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/radha/.local/lib/python3.10/site-packages (from requests>=2.32.1->datasets==2.19.2->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.32.1->datasets==2.19.2->-r requirements.txt (line 2)) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.32.1->datasets==2.19.2->-r requirements.txt (line 2)) (2020.6.20)
# Requirement already satisfied: cloudpickle>=1.2.1 in /home/radha/.local/lib/python3.10/site-packages (from submitit>=1.3.3->hydra-submitit-launcher==1.2.0->-r requirements.txt (line 5)) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in /home/radha/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/radha/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/radha/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/radha/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (6.30.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/radha/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/radha/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (3.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/radha/.local/lib/python3.10/site-packages (from torchvision>=0.10.0->lightning-bolts==0.7.0->-r requirements.txt (line 7)) (10.0.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/radha/.local/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit==3.7.1->-r requirements.txt (line 14)) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /home/radha/.local/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit==3.7.1->-r requirements.txt (line 14)) (4.3.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/radha/.local/lib/python3.10/site-packages (from jinja2->torch==2.3.0->-r requirements.txt (line 24)) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/radha/.local/lib/python3.10/site-packages (from sympy->torch==2.3.0->-r requirements.txt (line 24)) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/radha/.local/lib/python3.10/site-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/radha/.local/lib/python3.10/site-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/radha/.local/lib/python3.10/site-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/radha/.local/lib/python3.10/site-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.6->mne>=1.5->mne-bids==0.15.0->-r requirements.txt (line 8)) (2.4.7)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Installed required packages.

# %% [markdown]
# ### Step 4: Start your experiments!
#
# - Remember to download and copy the dataset to this directory: `Your_Dir/emg2qwerty/data`.
# - You may now start your experiments with any scripts! Below are examples of single-user training and testing (greedy decoding).
# - **There are two ways to track the logs:**
#   - 1. Keep `--multirun`, and the logs will not be printed here, but they will be saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/submitit_logs/`.
#   - 2. Comment out `--multirun` and the logs will be printed in this notebook, but they will not be saved.

# %% [markdown]
# #### Training
#
# - The checkpoints are saved in the folder `logs`, e.g., `logs/2025-02-09/18-24-15/checkpoints/`.

# %%
# Step 4: Training script (single-user training)
train_command = [
    "python3", "-m", "emg2qwerty.train",
    "user=single_user",
    "trainer.accelerator=gpu",
    "trainer.devices=1", "trainer.max_epochs=25"
]
subprocess.run(train_command, check=True)
print("Training completed.")
# Out:
# [2025-03-14 18:32:44,237][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: true
# checkpoint: null
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 25
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# [2025-03-14 18:32:44,238][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModule', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32}
# [2025-03-14 18:32:44,310][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# Global seed set to 1501
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /home/radha/.local/lib/python3.10/site-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# /home/radha/.local/lib/python3.10/site-packages/hydra/_internal/instantiate/_instantiate2.py:92: UnderReviewWarning: The feature LinearWarmupCosineAnnealingLR is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   return _target_(*args, **kwargs)
#
#   | Name     | Type       | Params
# ----------------------------------------
# 0 | model    | Sequential | 7.2 M
# 1 | ctc_loss | CTCLoss    | 0
# 2 | metrics  | ModuleDict | 0
# ----------------------------------------
# 7.2 M     Trainable params
# 0         Non-trainable params
# 7.2 M     Total params
# 28.875    Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/radha/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch 0:  94%|█████████▍| 120/127 [00:49<00:02,  2.43it/s, loss=128, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 0:  95%|█████████▌| 121/127 [00:50<00:02,  2.39it/s, loss=128, v_num=0]
# Epoch 0:  96%|█████████▌| 122/127 [00:50<00:02,  2.41it/s, loss=128, v_num=0]
# Epoch 0:  97%|█████████▋| 123/127 [00:50<00:01,  2.42it/s, loss=128, v_num=0]
# Epoch 0:  98%|█████████▊| 124/127 [00:50<00:01,  2.44it/s, loss=128, v_num=0]
# Epoch 0:  98%|█████████▊| 125/127 [00:51<00:00,  2.44it/s, loss=128, v_num=0]
# Epoch 0:  99%|█████████▉| 126/127 [00:51<00:00,  2.46it/s, loss=128, v_num=0]
# Epoch 0: 100%|██████████| 127/127 [00:51<00:00,  2.47it/s, loss=128, v_num=0]
# Epoch 0: 100%|██████████| 127/127 [00:51<00:00,  2.47it/s, loss=128, v_num=0]
# Epoch 0, global step 120: 'val/CER' reached 1292.46790 (best 1292.46790), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch
saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=9-step=1200.ckpt' as top 1
# Epoch 10:  94%|█████████▍| 120/127 [00:37<00:02,  3.21it/s, loss=2.37, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 10:  95%|█████████▌| 121/127 [00:38<00:01,  3.13it/s, loss=2.37, v_num=0]
# Epoch 10:  96%|█████████▌| 122/127 [00:38<00:01,  3.15it/s, loss=2.37, v_num=0]
# Epoch 10:  97%|█████████▋| 123/127 [00:38<00:01,  3.17it/s, loss=2.37, v_num=0]
# Epoch 10:  98%|█████████▊| 124/127 [00:38<00:00,  3.18it/s, loss=2.37, v_num=0]
# Epoch 10:  98%|█████████▊| 125/127 [00:39<00:00,  3.20it/s, loss=2.37, v_num=0]
# Epoch 10:  99%|█████████▉| 126/127 [00:39<00:00,  3.22it/s, loss=2.37, v_num=0]
# Epoch 10: 100%|██████████| 127/127 [00:39<00:00,  3.24it/s, loss=2.37, v_num=0]
# Epoch 10: 100%|██████████| 127/127 [00:39<00:00,  3.24it/s, loss=2.37, v_num=0]
# Epoch 10, global step 1320: 'val/CER' reached 88.41383 (best 88.41383), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=10-step=1320.ckpt' as top 1
# Epoch 11:  94%|█████████▍| 120/127 [00:39<00:02,  3.06it/s, loss=2.13, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 11:  95%|█████████▌| 121/127 [00:40<00:02,  2.99it/s, loss=2.13, v_num=0]
# Epoch 11:  96%|█████████▌| 122/127 [00:40<00:01,  3.01it/s, loss=2.13, v_num=0]
# Epoch 11:  97%|█████████▋| 123/127 [00:40<00:01,  3.03it/s, loss=2.13, v_num=0]
# Epoch 11:  98%|█████████▊| 124/127 [00:40<00:00,  3.04it/s, loss=2.13, v_num=0]
# Epoch 11:  98%|█████████▊| 125/127 [00:40<00:00,  3.05it/s, loss=2.13, v_num=0]
# Epoch 11:  99%|█████████▉| 126/127 [00:41<00:00,  3.07it/s, loss=2.13, v_num=0]
# Epoch 11: 100%|██████████| 127/127 [00:41<00:00,  3.09it/s, loss=2.13, v_num=0]
# Epoch 11: 100%|██████████| 127/127 [00:41<00:00,  3.09it/s, loss=2.13, v_num=0]
# Epoch 11, global step 1440: 'val/CER' reached 85.37882 (best 85.37882), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=11-step=1440.ckpt' as top 1
# Epoch 12:  94%|█████████▍| 120/127 [00:39<00:02,  3.05it/s, loss=1.96, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 12:  95%|█████████▌| 121/127 [00:40<00:02,  2.99it/s, loss=1.96, v_num=0]
# Epoch 12:  96%|█████████▌| 122/127 [00:40<00:01,  3.01it/s, loss=1.96, v_num=0]
# Epoch 12:  97%|█████████▋| 123/127 [00:40<00:01,  3.02it/s, loss=1.96, v_num=0]
# Epoch 12:  98%|█████████▊| 124/127 [00:40<00:00,  3.04it/s, loss=1.96, v_num=0]
# Epoch 12:  98%|█████████▊| 125/127 [00:40<00:00,  3.05it/s, loss=1.96, v_num=0]
# Epoch 12:  99%|█████████▉| 126/127 [00:41<00:00,  3.07it/s, loss=1.96, v_num=0]
# Epoch 12: 100%|██████████| 127/127 [00:41<00:00,  3.09it/s, loss=1.96, v_num=0]
# Epoch 12: 100%|██████████| 127/127 [00:41<00:00,  3.09it/s, loss=1.96, v_num=0]
# Epoch 12, global step 1560: 'val/CER' reached 78.59991 (best 78.59991), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=12-step=1560.ckpt' as top 1
# Epoch 13:  94%|█████████▍| 120/127 [00:41<00:02,  2.87it/s, loss=1.87, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 13:  95%|█████████▌| 121/127 [00:42<00:02,  2.82it/s, loss=1.87, v_num=0]
# Epoch 13:  96%|█████████▌| 122/127 [00:42<00:01,  2.84it/s, loss=1.87, v_num=0]
# Epoch 13:  97%|█████████▋| 123/127 [00:43<00:01,  2.85it/s, loss=1.87, v_num=0]
# Epoch 13:  98%|█████████▊| 124/127 [00:43<00:01,  2.87it/s, loss=1.87, v_num=0]
# Epoch 13:  98%|█████████▊| 125/127 [00:43<00:00,  2.88it/s, loss=1.87, v_num=0]
# Epoch 13:  99%|█████████▉| 126/127 [00:43<00:00,  2.90it/s, loss=1.87, v_num=0]
# Epoch 13: 100%|██████████| 127/127 [00:43<00:00,  2.92it/s, loss=1.87, v_num=0]
# Epoch 13: 100%|██████████| 127/127 [00:43<00:00,  2.92it/s, loss=1.87, v_num=0]
# Epoch 13, global step 1680: 'val/CER' reached 71.35578 (best 71.35578), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=13-step=1680.ckpt' as top 1
# Epoch 14:  94%|█████████▍| 120/127 [00:39<00:02,  3.02it/s, loss=1.57, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 14:  95%|█████████▌| 121/127 [00:40<00:02,  2.96it/s, loss=1.57, v_num=0]
# Epoch 14:  96%|█████████▌| 122/127 [00:40<00:01,  2.98it/s, loss=1.57, v_num=0]
# Epoch 14:  97%|█████████▋| 123/127 [00:41<00:01,  3.00it/s, loss=1.57, v_num=0]
# Epoch 14:  98%|█████████▊| 124/127 [00:41<00:00,  3.01it/s, loss=1.57, v_num=0]
# Epoch 14:  98%|█████████▊| 125/127 [00:41<00:00,  3.01it/s, loss=1.57, v_num=0]
# Epoch 14:  99%|█████████▉| 126/127 [00:41<00:00,  3.03it/s, loss=1.57, v_num=0]
# Epoch 14: 100%|██████████| 127/127 [00:41<00:00,  3.05it/s, loss=1.57, v_num=0]
# Epoch 14: 100%|██████████| 127/127 [00:41<00:00,  3.05it/s, loss=1.57, v_num=0]
# Epoch 14, global step 1800: 'val/CER' reached 48.75941 (best 48.75941), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=14-step=1800.ckpt' as top 1
# Epoch 15:  94%|█████████▍| 120/127 [00:40<00:02,  2.96it/s, loss=1.38, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 15:  95%|█████████▌| 121/127 [00:41<00:02,  2.90it/s, loss=1.38, v_num=0]
# Epoch 15:  96%|█████████▌| 122/127 [00:41<00:01,  2.91it/s, loss=1.38, v_num=0]
# Epoch 15:  97%|█████████▋| 123/127 [00:41<00:01,  2.93it/s, loss=1.38, v_num=0]
# Epoch 15:  98%|█████████▊| 124/127 [00:42<00:01,  2.95it/s, loss=1.38, v_num=0]
# Epoch 15:  98%|█████████▊| 125/127 [00:42<00:00,  2.95it/s, loss=1.38, v_num=0]
# Epoch 15:  99%|█████████▉| 126/127 [00:42<00:00,  2.96it/s, loss=1.38, v_num=0]
# Epoch 15: 100%|██████████| 127/127 [00:42<00:00,  2.98it/s, loss=1.38, v_num=0]
# Epoch 15: 100%|██████████| 127/127 [00:42<00:00,  2.98it/s, loss=1.38, v_num=0]
# Epoch 15, global step 1920: 'val/CER' reached 37.79353 (best 37.79353), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=15-step=1920.ckpt' as top 1
# Epoch 16:  94%|█████████▍| 120/127 [00:40<00:02,  2.97it/s, loss=1.33, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 16:  95%|█████████▌| 121/127 [00:41<00:02,  2.91it/s, loss=1.33, v_num=0]
# Epoch 16:  96%|█████████▌| 122/127 [00:41<00:01,  2.93it/s, loss=1.33, v_num=0]
# Epoch 16:  97%|█████████▋| 123/127 [00:41<00:01,  2.94it/s, loss=1.33, v_num=0]
# Epoch 16:  98%|█████████▊| 124/127 [00:41<00:01,  2.96it/s, loss=1.33, v_num=0]
# Epoch 16:  98%|█████████▊| 125/127 [00:41<00:00,  2.98it/s, loss=1.33, v_num=0]
# Epoch 16:  99%|█████████▉| 126/127 [00:42<00:00,  2.99it/s, loss=1.33, v_num=0]
# Epoch 16: 100%|██████████| 127/127 [00:42<00:00,  3.01it/s, loss=1.33, v_num=0]
# Epoch 16: 100%|██████████| 127/127 [00:42<00:00,  3.01it/s, loss=1.33, v_num=0]
# Epoch 16, global step 2040: 'val/CER' reached 34.73637 (best 34.73637), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=16-step=2040.ckpt' as top 1
# Epoch 17:  94%|█████████▍| 120/127 [00:39<00:02,  3.04it/s, loss=1.38, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 17:  95%|█████████▌| 121/127 [00:40<00:02,  2.99it/s, loss=1.38, v_num=0]
# Epoch 17:  96%|█████████▌| 122/127 [00:40<00:01,  3.01it/s, loss=1.38, v_num=0]
# Epoch 17:  97%|█████████▋| 123/127 [00:40<00:01,  3.03it/s, loss=1.38, v_num=0]
# Epoch 17:  98%|█████████▊| 124/127 [00:40<00:00,  3.04it/s, loss=1.38, v_num=0]
# Epoch 17:  98%|█████████▊| 125/127 [00:40<00:00,  3.06it/s, loss=1.38, v_num=0]
# Epoch 17:  99%|█████████▉| 126/127 [00:40<00:00,  3.07it/s, loss=1.38, v_num=0]
# Epoch 17: 100%|██████████| 127/127 [00:41<00:00,  3.09it/s, loss=1.38, v_num=0]
# Epoch 17: 100%|██████████| 127/127 [00:41<00:00,  3.09it/s, loss=1.38, v_num=0]
# Epoch 17, global step 2160: 'val/CER' was not in top 1
# Epoch 18:  94%|█████████▍| 120/127 [00:39<00:02,  3.04it/s, loss=1.23, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 18:  95%|█████████▌| 121/127 [00:40<00:02,  2.99it/s, loss=1.23, v_num=0]
# Epoch 18:  96%|█████████▌| 122/127 [00:40<00:01,  3.01it/s, loss=1.23, v_num=0]
# Epoch 18:  97%|█████████▋| 123/127 [00:40<00:01,  3.02it/s, loss=1.23, v_num=0]
# Epoch 18:  98%|█████████▊| 124/127 [00:40<00:00,  3.04it/s, loss=1.23, v_num=0]
# Epoch 18:  98%|█████████▊| 125/127 [00:41<00:00,  3.04it/s, loss=1.23, v_num=0]
# Epoch 18:  99%|█████████▉| 126/127 [00:41<00:00,  3.06it/s, loss=1.23, v_num=0]
# Epoch 18: 100%|██████████| 127/127 [00:41<00:00,  3.07it/s, loss=1.23, v_num=0]
# Epoch 18: 100%|██████████| 127/127 [00:41<00:00,  3.07it/s, loss=1.23, v_num=0]
# Epoch 18, global step 2280: 'val/CER' was not in top 1
# Epoch 19:  94%|█████████▍| 120/127 [00:39<00:02,  3.04it/s, loss=1.2, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 19:  95%|█████████▌| 121/127 [00:40<00:02,  2.99it/s, loss=1.2, v_num=0]
# Epoch 19:  96%|█████████▌| 122/127 [00:40<00:01,  3.01it/s, loss=1.2, v_num=0]
# Epoch 19:  97%|█████████▋| 123/127 [00:40<00:01,  3.02it/s, loss=1.2, v_num=0]
# Epoch 19:  98%|█████████▊| 124/127 [00:40<00:00,  3.04it/s, loss=1.2, v_num=0]
# Epoch 19:  98%|█████████▊| 125/127 [00:41<00:00,  3.04it/s, loss=1.2, v_num=0]
# Epoch 19:  99%|█████████▉| 126/127 [00:41<00:00,  3.06it/s, loss=1.2, v_num=0]
# Epoch 19: 100%|██████████| 127/127 [00:41<00:00,  3.07it/s, loss=1.2, v_num=0]
# Epoch 19: 100%|██████████| 127/127 [00:41<00:00,  3.07it/s, loss=1.2, v_num=0]
# Epoch 19, global step 2400: 'val/CER' reached 31.05893 (best 31.05893), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=19-step=2400.ckpt' as top 1
# Epoch 20:  94%|█████████▍| 120/127 [00:39<00:02,  3.02it/s, loss=1.13, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 20:  95%|█████████▌| 121/127 [00:40<00:02,  2.96it/s, loss=1.13, v_num=0]
# Epoch 20:  96%|█████████▌| 122/127 [00:40<00:01,  2.98it/s, loss=1.13, v_num=0]
# Epoch 20:  97%|█████████▋| 123/127 [00:41<00:01,  3.00it/s, loss=1.13, v_num=0]
# Epoch 20:  98%|█████████▊| 124/127 [00:41<00:00,  3.01it/s, loss=1.13, v_num=0]
# Epoch 20:  98%|█████████▊| 125/127 [00:41<00:00,  3.02it/s, loss=1.13, v_num=0]
# Epoch 20:  99%|█████████▉| 126/127 [00:41<00:00,  3.03it/s, loss=1.13, v_num=0]
# Epoch 20: 100%|██████████| 127/127 [00:41<00:00,  3.05it/s, loss=1.13, v_num=0]
# Epoch 20: 100%|██████████| 127/127 [00:41<00:00,  3.05it/s, loss=1.13, v_num=0]
# Epoch 20, global step 2520: 'val/CER' reached 30.03988 (best 30.03988), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=20-step=2520.ckpt' as top 1
# Epoch 21:  94%|█████████▍| 120/127 [00:40<00:02,  2.94it/s, loss=1.06, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 21:  95%|█████████▌| 121/127 [00:41<00:02,  2.88it/s, loss=1.06, v_num=0]
# Epoch 21:  96%|█████████▌| 122/127 [00:42<00:01,  2.90it/s, loss=1.06, v_num=0]
# Epoch 21:  97%|█████████▋| 123/127 [00:42<00:01,  2.91it/s, loss=1.06, v_num=0]
# Epoch 21:  98%|█████████▊| 124/127 [00:42<00:01,  2.93it/s, loss=1.06, v_num=0]
# Epoch 21:  98%|█████████▊| 125/127 [00:42<00:00,  2.95it/s, loss=1.06, v_num=0]
# Epoch 21:  99%|█████████▉| 126/127 [00:42<00:00,  2.96it/s, loss=1.06, v_num=0]
# Epoch 21: 100%|██████████| 127/127 [00:42<00:00,  2.98it/s, loss=1.06, v_num=0]
# Epoch 21: 100%|██████████| 127/127 [00:42<00:00,  2.98it/s, loss=1.06, v_num=0]
# Epoch 21, global step 2640: 'val/CER' reached 29.02082 (best 29.02082), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=21-step=2640.ckpt' as top 1
# Epoch 22:  94%|█████████▍| 120/127 [00:39<00:02,  3.01it/s, loss=1.05, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 22:  95%|█████████▌| 121/127 [00:40<00:02,  2.96it/s, loss=1.05, v_num=0]
# Epoch 22:  96%|█████████▌| 122/127 [00:41<00:01,  2.97it/s, loss=1.05, v_num=0]
# Epoch 22:  97%|█████████▋| 123/127 [00:41<00:01,  2.99it/s, loss=1.05, v_num=0]
# Epoch 22:  98%|█████████▊| 124/127 [00:41<00:00,  3.01it/s, loss=1.05, v_num=0]
# Epoch 22:  98%|█████████▊| 125/127 [00:41<00:00,  3.02it/s, loss=1.05, v_num=0]
# Epoch 22:  99%|█████████▉| 126/127 [00:41<00:00,  3.03it/s, loss=1.05, v_num=0]
# Epoch 22: 100%|██████████| 127/127 [00:41<00:00,  3.05it/s, loss=1.05, v_num=0]
# Epoch 22: 100%|██████████| 127/127 [00:41<00:00,  3.05it/s, loss=1.05, v_num=0]
# Epoch 22, global step 2760: 'val/CER' reached 28.22330 (best 28.22330), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=22-step=2760.ckpt' as top 1
# Epoch 23:  94%|█████████▍| 120/127 [00:40<00:02,  2.98it/s, loss=1.02, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 23:  95%|█████████▌| 121/127 [00:41<00:02,  2.93it/s, loss=1.02, v_num=0]
# Epoch 23:  96%|█████████▌| 122/127 [00:41<00:01,  2.95it/s, loss=1.02, v_num=0]
# Epoch 23:  97%|█████████▋| 123/127 [00:41<00:01,  2.96it/s, loss=1.02, v_num=0]
# Epoch 23:  98%|█████████▊| 124/127 [00:41<00:01,  2.98it/s, loss=1.02, v_num=0]
# Epoch 23:  98%|█████████▊| 125/127 [00:41<00:00,  2.98it/s, loss=1.02, v_num=0]
# Epoch 23:  99%|█████████▉| 126/127 [00:42<00:00,  3.00it/s, loss=1.02, v_num=0]
# Epoch 23: 100%|██████████| 127/127 [00:42<00:00,  3.02it/s, loss=1.02, v_num=0]
# Epoch 23: 100%|██████████| 127/127 [00:42<00:00,  3.02it/s, loss=1.02, v_num=0]
# Epoch 23, global step 2880: 'val/CER' reached 27.60301 (best 27.60301), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=23-step=2880.ckpt' as top 1
# Epoch 24:  94%|█████████▍| 120/127 [00:40<00:02,  2.96it/s, loss=1.02, v_num=0]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Epoch 24:  95%|█████████▌| 121/127 [00:41<00:02,  2.91it/s, loss=1.02, v_num=0]
# Epoch 24:  96%|█████████▌| 122/127 [00:41<00:01,  2.93it/s, loss=1.02, v_num=0]
# Epoch 24:  97%|█████████▋| 123/127 [00:41<00:01,  2.94it/s, loss=1.02, v_num=0]
# Epoch 24:  98%|█████████▊| 124/127 [00:41<00:01,  2.96it/s, loss=1.02, v_num=0]
# Epoch 24:  98%|█████████▊| 125/127 [00:42<00:00,  2.97it/s, loss=1.02, v_num=0]
# Epoch 24:  99%|█████████▉| 126/127 [00:42<00:00,  2.99it/s, loss=1.02, v_num=0]
# Epoch 24: 100%|██████████| 127/127 [00:42<00:00,  3.00it/s, loss=1.02, v_num=0]
# Epoch 24: 100%|██████████| 127/127 [00:42<00:00,  3.00it/s, loss=1.02, v_num=0]
# Epoch 24, global step 3000: 'val/CER' reached 27.58086 (best 27.58086), saving model to '/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=24-step=3000.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 127/127 [00:42<00:00,  2.97it/s, loss=1.02, v_num=0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:00<00:00,  9.22it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          val/CER            27.580860137939453
#          val/DER             2.259636640548706
#          val/IER             6.114311218261719
#          val/SER            19.206911087036133
#         val/loss            0.8756574392318726
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:02<00:00,  2.98s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test/CER              28.506591796875
#         test/DER            2.3989624977111816
#         test/IER             5.208558559417725
#         test/SER            20.899070739746094
#         test/loss           0.8732985854148865
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# {'val_metrics': [{'val/loss': 0.8756574392318726,
#                   'val/CER': 27.580860137939453,
#                   'val/IER': 6.114311218261719,
#                   'val/DER': 2.259636640548706,
#                   'val/SER': 19.206911087036133}],
#  'test_metrics': [{'test/loss': 0.8732985854148865,
#                    'test/CER': 28.506591796875,
#                    'test/IER': 5.208558559417725,
#                    'test/DER': 2.3989624977111816,
#                    'test/SER': 20.899070739746094}],
#  'best_checkpoint': '/home/radha/Desktop/courses/ECE '
#                     'C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=24-step=3000.ckpt'}
# Training completed.

# %% [markdown]
# #### Testing:
#
# - Replace `Your_Path_to_Checkpoint` with your checkpoint path.

# %%
# Step 5: Testing script (replace with actual checkpoint path)
CHECKPOINT_PATH = "'/home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=24-step=3000.ckpt'"  # Update this path

test_command = [
    "python3", "-m", "emg2qwerty.train",
    "user=single_user",
    f"checkpoint={CHECKPOINT_PATH}",
    "train=False",
    "trainer.accelerator=gpu",
    "decoder=ctc_greedy",
    "hydra.launcher.mem_gb=64"
]
subprocess.run(test_command, check=True)
print("Testing completed.")
# Out:
# [2025-03-14 18:51:52,115][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: ${hydra:runtime.cwd}/data
# to_tensor:
#   _target_: emg2qwerty.transforms.ToTensor
#   fields:
#   - emg_left
#   - emg_right
# band_rotation:
#   _target_: emg2qwerty.transforms.ForEach
#   transform:
#     _target_: emg2qwerty.transforms.RandomBandRotation
#     offsets:
#     - -1
#     - 0
#     - 1
# temporal_jitter:
#   _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#   max_offset: 120
# logspec:
#   _target_: emg2qwerty.transforms.LogSpectrogram
#   n_fft: 64
#   hop_length: 16
# specaug:
#   _target_: emg2qwerty.transforms.SpecAugment
#   n_time_masks: 3
#   time_mask_param: 25
#   n_freq_masks: 2
#   freq_mask_param: 4
# transforms:
#   train:
#   - ${to_tensor}
#   - ${band_rotation}
#   - ${temporal_jitter}
#   - ${logspec}
#   - ${specaug}
#   val:
#   - ${to_tensor}
#   - ${logspec}
#   test: ${transforms.val}
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.001
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 32
# num_workers: 4
# train: false
# checkpoint: /home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=24-step=3000.ckpt
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 150
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# [2025-03-14 18:51:52,118][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModule', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32}
# [2025-03-14 18:51:52,215][__main__][INFO] - Loading module from checkpoint /home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-32-44/checkpoints/epoch=24-step=3000.ckpt
# Global seed set to 1501
# [2025-03-14 18:51:52,334][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /home/radha/Desktop/courses/ECE C247/project_git/emg2qwerty/logs/2025-03-14/18-51-52/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# /home/radha/.local/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.95it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          val/CER            27.580860137939453
#          val/DER             2.259636640548706
#          val/IER             6.114311218261719
#          val/SER            19.206911087036133
#         val/loss            0.8756574392318726
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:02<00:00,  2.97s/it]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test/CER              28.506591796875
#         test/DER            2.3989624977111816
#         test/IER             5.208558559417725
#         test/SER            20.899070739746094
#         test/loss           0.8732985854148865
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# {'val_metrics': [{'val/loss': 0.8756574392318726,
#                   'val/CER': 27.580860137939453,
#                   'val/IER': 6.114311218261719,
#                   'val/DER': 2.259636640548706,
#                   'val/SER': 19.206911087036133}],
#  'test_metrics': [{'test/loss': 0.8732985854148865,
#                    'test/CER': 28.506591796875,
#                    'test/IER': 5.208558559417725,
#                    'test/DER': 2.3989624977111816,
#                    'test/SER': 20.899070739746094}],
#  'best_checkpoint': ''}
# Testing completed.
